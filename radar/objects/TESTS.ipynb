# %%
import sqlite3
import json

# %%
connection = sqlite3.connect('C:/Users/PC/Desktop/python_code/database3.db')
cursor = connection.cursor()
# Создаем таблицу

cursor.execute('''
    CREATE TABLE IF NOT EXISTS Input_parameters (
    Number_test INTEGER PRIMARY KEY,
    Type_of_signal_modul INTEGER,
    Wavelength float ,
    duration_impulse float,
    Losses float,
    Noise_T float,
    Max_azimuth float,
    Min_azimuth float,
    Azimuth_scanning_step float,
    max_value_of_the_seat_angle float ,
    min_value_of_the_seat_angle float,
    Angle_scanning_step float,
    ESS_goals float,
    probability_of_correct_detection float,
    probability_of_false_alarm float,
    Number_of_impulses integer,
    Coeff_of_coherence float,
    Potential_radar_station float,
    Impulse_power float ,
    Antenna_aperture_width float,
    Antenna_aperture_height float,
    Antenna_area_utilization_factor float,
    Signal_to_noise_ratio float,
    Type_of_fluctuation_of_target integer,
    Oblique_target_range float,
    Azimuth_of_target float,
    Antenna_position_angle float ,
    Antenna_azimuth float,
    Proportionality_coefficient_RMSD float,
    Proportionality_coefficient_ARP float,
    Width_of_signal_spectrum float,
    Duration_of_FCM_discretion float,
    Frequency_of_LFM_radiation float
    )
''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS Output_parameters (
    Number_test INTEGER PRIMARY KEY,
    Estimation_delta_beta float,
    Epsilent_min float,
    Epsilent_max float,
    Estimation_D_min float,
    Estimation_D_max float,
    T_O float,
    D_max float,
    P_detection float,
    sigma_D float ,
    sigma_V_d float,
    sigma_beta float,
    sigma_epsilent float,
    sigma_x float,
    sigma_y float,
    sigma_x_y float,
    sigma_h float,
    delta_D float,
    delta_V float ,
    delta_beta float,
    delta_Epsilent float,
    delta_h float
    )
''')
connection.commit()
connection.close()

# %%
with open('???.json') as json_file:
    json_obj = json.load(json_file)
    connection = sqlite3.connect('C:/Users/PC/Desktop/python_code/database2.db')
    cursor = connection.cursor()
    for item in json_obj:
        Type_of_signal_modul=item.get("Type_of_signal_modul")
        Wavelength=item.get("Wavelength")
        duration_impulse=item.get("duration_impulse")
        Losses=item.get("Losses")
        Noise_T=item.get("Noise_T")
        Max_azimuth=item.get("Max_azimuth")
        Min_azimuth=item.get("Min_azimuth")
        Azimuth_scanning_step=item.get("Azimuth_scanning_step")
        max_value_of_the_seat_angle=item.get("max_value_of_the_seat_angle")
        min_value_of_the_seat_angle=item.get("min_value_of_the_seat_angle")
        Angle_scanning_step=item.get("Angle_scanning_step")
        ESS_goals=item.get("ESS_goals")
        probability_of_correct_detection=item.get("probability_of_correct_detection")
        probability_of_false_alarm=item.get("probability_of_false_alarm")
        Number_of_impulses=item.get("Number_of_impulses")
        Coeff_of_coherence=item.get("Coeff_of_coherence")
        Potential_radar_station=item.get("Potential_radar_station")
        Impulse_power=item.get("Impulse_power")
        Antenna_aperture_width=item.get("Antenna_aperture_width")
        Antenna_aperture_height=item.get("Antenna_aperture_height")
        Antenna_area_utilization_factor=item.get("Antenna_area_utilization_factor")
        Signal_to_noise_ratio=item.get("Signal_to_noise_ratio")
        Type_of_fluctuation_of_target=item.get("Type_of_fluctuation_of_target")
        Oblique_target_range=item.get("Oblique_target_range")
        Azimuth_of_target=item.get("Azimuth_of_target")
        Antenna_position_angle=item.get("Antenna_position_angle")
        Antenna_azimuth=item.get("Antenna_azimuth")
        Proportionality_coefficient_RMSD=item.get("Proportionality_coefficient_RMSD")
        Proportionality_coefficient_ARP=item.get("Wavelength")
        Width_of_signal_spectrum=item.get("Width_of_signal_spectrum")
        Duration_of_FCM_discretion=item.get("Duration_of_FCM_discretion")
        Frequency_of_LFM_radiation=item.get("Frequency_of_LFM_radiation")
        cursor.execute('''insert into Input_parameters(Type_of_signal_modul, Wavelength,
            duration_impulse, Losses, Noise_T, Max_azimuth, Min_azimuth,
            Azimuth_scanning_step, max_value_of_the_seat_angle, min_value_of_the_seat_angle,
            Angle_scanning_step, ESS_goals, probability_of_correct_detection,
            probability_of_false_alarm, Number_of_impulses,
            Coeff_of_coherence, Potential_radar_station, Impulse_power,
            Antenna_aperture_width, Antenna_aperture_height,
            Antenna_area_utilization_factor, Signal_to_noise_ratio,
            Type_of_fluctuation_of_target, Oblique_target_range,
            Azimuth_of_target, Antenna_position_angle, Antenna_azimuth,
            Proportionality_coefficient_RMSD, Proportionality_coefficient_ARP,
            Width_of_signal_spectrum, Duration_of_FCM_discretion, Frequency_of_LFM_radiation) 
            value(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,)''',
            (Type_of_signal_modul, Wavelength,
            duration_impulse, Losses, Noise_T, Max_azimuth, Min_azimuth,
            Azimuth_scanning_step, max_value_of_the_seat_angle, min_value_of_the_seat_angle,
            Angle_scanning_step, ESS_goals, probability_of_correct_detection,
            probability_of_false_alarm, Number_of_impulses,
            Coeff_of_coherence, Potential_radar_station, Impulse_power,
            Antenna_aperture_width, Antenna_aperture_height,
            Antenna_area_utilization_factor, Signal_to_noise_ratio,
            Type_of_fluctuation_of_target, Oblique_target_range,
            Azimuth_of_target, Antenna_position_angle, Antenna_azimuth,
            Proportionality_coefficient_RMSD, Proportionality_coefficient_ARP,
            Width_of_signal_spectrum, Duration_of_FCM_discretion, Frequency_of_LFM_radiation))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with open('???.json') as json_file:
#       2     json_obj = json.load(json_file)
#       3     connection = sqlite3.connect('C:/Users/PC/Desktop/python_code/database2.db')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: '???.json'

# %%
  
# create connection to the  
# database geek 
connection = sqlite3.connect('C:/Users/PC/Desktop/python_code/database2.db')
cursor = connection.cursor()
  
# drop table 
cursor.execute("DROP TABLE Input_parameters") 
cursor.execute("DROP TABLE Output_parameters") 
  
print("data dropped successfully") 
  
# close the connection 
connection.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 7
#       4 cursor = connection.cursor()
#       6 # drop table
# ----> 7 cursor.execute("DROP TABLE Input_parameters")
#       8 cursor.execute("DROP TABLE Output_parameters")
#      10 print("data dropped successfully")
#
# OperationalError: database is locked

# %%
connection = sqlite3.connect('C:/Users/PC/Desktop/python_code/database2.db')
cursor = connection.cursor()
cursor.execute('INSERT INTO Output_parameters (Number_test, sigma_x, sigma_y, sigma_h) VALUES (?, ?, ?, ?)', (1, 2, 3, 5))  
cursor.execute('UPDATE Output_parameters SET sigma_x=?, sigma_y=?, sigma_h=? where Number_test = ?  ', (4, 5, 9, 1))
# close the connection 
connection.commit()
connection.close()
